# %%
import numpy as np
import cv2
import imutils
import matplotlib.pyplot as plt
import pandas as pd
import json
import os, sys

labels = []

for i in os.listdir("labels/"):
    with open(f"labels/{i}") as f:
        temp = []
        for line in f:
            temp.append(line.split()[4:8])
        if(len(temp) == 4):
            labels = temp
        else:
            labels = []
        
        
        if(labels != []):
            print(labels)
        #     i = i.split(".")[0]
        #     image = cv2.imread(f"images/{i}.jpg")
        #     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #     hands = ["myLeft", "myRight", "yourLeft", "yourRight"]
        #     for c, label in enumerate(labels):
        #         cv2.rectangle(image, (int(label[0]), int(label[1])), (int(label[2]), int(label[3])), (255,0,0), 4)
        #         cv2.putText(image, hands[c], (int(label[0]), int(label[1])-10),
        #                         cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)
        #         cv2.circle(image,(int(label[0]),int(label[1])), 8, (0,255,0), -1)
        #         cv2.circle(image,(int(label[2]),int(label[3])), 8, (0,255,0), -1)
        #     plt.imshow(image)
        #     plt.show()
# Out:
# [['591', '192', '1213', '719']]
# [['11', '167', '164', '602']]
# [['566', '417', '752', '611']]
# [['549', '256', '1086', '577']]
# [['522', '307', '1116', '610']]
# [['244', '125', '679', '471']]
# [['355', '231', '843', '584']]
# [['463', '160', '630', '306']]
# [['455', '163', '605', '308']]
# [['445', '153', '601', '313']]
# [['704', '351', '736', '430']]
# [['673', '321', '721', '390']]
# [['690', '303', '824', '408']]
# [['616', '123', '877', '461']]
# [['643', '303', '786', '473']]
# [['662', '275', '807', '420']]
# [['658', '311', '812', '435']]
# [['282', '570', '412', '715']]
# [['262', '549', '440', '717']]
# [['261', '561', '437', '718']]
# [['591', '297', '697', '498']]
# [['597', '383', '697', '610']]
# [['600', '363', '696', '587']]
# [['503', '333', '685', '553']]
# [['581', '564', '805', '719']]
# [['579', '586', '745', '719']]
# [['555', '503', '742', '719']]
# [['558', '503', '755', '719']]
# [['445', '677', '610', '719']]
# [['534', '295', '821', '622']]
# ...
